# %%
import requests
import pandas as pd
import time
import json
import os
from typing import Dict, List, Optional

class AlphaFoldSearcher:
    def __init__(self):
        self.base_url = "https://rest.uniprot.org"
        self.search_url = "https://rest.uniprot.org/uniprotkb/search"
        self.alphafold_url = "https://alphafold.ebi.ac.uk/api"
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
            'Accept': 'application/json'
        })
    
    def search_alphafold_by_name(self, name: str, max_results: int = 10) -> Dict:
        """
        Поиск структур AlphaFold по названию белка
        """
        try:
            # Сначала ищем в UniProt чтобы получить accession numbers
            uniprot_results = self._search_uniprot_by_name(name, max_results)
            
            if not uniprot_results:
                return {
                    'success': True,
                    'found': False,
                    'count': 0,
                    'alphafold_ids': [],
                    'detailed_results': [],
                    'error': None
                }
            
            # Теперь проверяем наличие структур в AlphaFold для каждого найденного UniProt ID
            alphafold_ids = []
            detailed_results = []
            
            for uniprot_result in uniprot_results:
                uniprot_id = uniprot_result['uniprot_id']
                alphafold_id = self._get_alphafold_structure(uniprot_id)
                
                if alphafold_id:
                    alphafold_ids.append(alphafold_id)
                    
                    # Получаем детальную информацию о структуре AlphaFold
                    af_info = self._get_alphafold_info(alphafold_id)
                    
                    detailed_results.append({
                        'alphafold_id': alphafold_id,
                        'uniprot_id': uniprot_id,
                        'relevance_score': uniprot_result['relevance_score'],
                        'relevance_level': uniprot_result['relevance_level'],
                        'protein_name': uniprot_result['protein_name'],
                        'gene_name': uniprot_result['gene_name'],
                        'organism': uniprot_result['organism'],
                        'plddt_score': af_info.get('plddt', 'N/A'),
                        'confidence_level': af_info.get('confidence', 'N/A'),
                        'model_url': af_info.get('model_url', 'N/A'),
                        'sequence_length': uniprot_result.get('length', 0)
                    })
            
            return {
                'success': True,
                'found': len(alphafold_ids) > 0,
                'count': len(alphafold_ids),
                'alphafold_ids': alphafold_ids,
                'detailed_results': detailed_results,
                'error': None
            }
            
        except Exception as e:
            return {
                'success': False,
                'found': False,
                'count': 0,
                'alphafold_ids': [],
                'detailed_results': [],
                'error': f"AlphaFold search error: {str(e)}"
            }
    
    def _search_uniprot_by_name(self, name: str, max_results: int) -> List[Dict]:
        """
        Поиск в UniProt по названию (внутренний метод)
        """
        try:
            # Упрощаем запрос - ищем по любому совпадению в названии
            query = f'({name}) AND reviewed:true'
            params = {
                'query': query,
                'fields': 'accession,protein_name,gene_names,organism_name,sequence,length',
                'size': max_results,
                'format': 'json'
            }
            
            response = self.session.get(self.search_url, params=params, timeout=30)
            response.raise_for_status()
            data = response.json()
            
            results = data.get('results', [])
            uniprot_results = []
            
            for result in results:
                uniprot_id = result.get('primaryAccession')
                if uniprot_id:
                    protein_name = result.get('proteinDescription', {}).get('recommendedName', {}).get('fullName', {}).get('value', 'N/A')
                    gene_name = result.get('genes', [{}])[0].get('geneName', {}).get('value', 'N/A') if result.get('genes') else 'N/A'
                    
                    # Упрощенный расчет релевантности
                    relevance_score = self._calculate_simple_relevance(name, protein_name, gene_name)
                    
                    # Если релевантность выше порога, добавляем результат
                    if relevance_score >= 30:  # Понижаем порог для большего охвата
                        uniprot_results.append({
                            'uniprot_id': uniprot_id,
                            'relevance_score': relevance_score,
                            'relevance_level': self._get_relevance_level(relevance_score),
                            'protein_name': protein_name,
                            'gene_name': gene_name,
                            'organism': result.get('organism', {}).get('scientificName', 'N/A'),
                            'length': result.get('sequence', {}).get('length', 0)
                        })
            
            # Сортируем по релевантности
            uniprot_results.sort(key=lambda x: x['relevance_score'], reverse=True)
            return uniprot_results[:max_results]
            
        except Exception as e:
            print(f"Ошибка поиска в UniProt: {e}")
            return []
    
    def _calculate_simple_relevance(self, query_name: str, protein_name: str, gene_name: str) -> float:
        """
        Упрощенный расчет релевантности - больше результатов
        """
        query_lower = query_name.lower()
        protein_lower = protein_name.lower()
        gene_lower = gene_name.lower()
        
        # Точное совпадение
        if query_lower == protein_lower or query_lower == gene_lower:
            return 100.0
        
        # Содержит полное название
        if query_lower in protein_lower or query_lower in gene_lower:
            return 90.0
        
        # Содержит ключевые слова
        query_words = query_lower.split()
        protein_words = protein_lower.split()
        gene_words = gene_lower.split()
        
        # Считаем совпадения слов
        protein_matches = sum(1 for word in query_words if word in protein_lower)
        gene_matches = sum(1 for word in query_words if word in gene_lower)
        total_matches = protein_matches + gene_matches
        
        if total_matches > 0:
            return min(80.0, total_matches * 20.0)
        
        # Частичные совпадения слов
        partial_matches = 0
        for q_word in query_words:
            for p_word in protein_words:
                if q_word in p_word or p_word in q_word:
                    partial_matches += 1
            for g_word in gene_words:
                if q_word in g_word or g_word in q_word:
                    partial_matches += 1
        
        if partial_matches > 0:
            return min(60.0, partial_matches * 15.0)
        
        # Минимальная релевантность для всех результатов
        return 30.0
    
    def _get_alphafold_structure(self, uniprot_id: str) -> Optional[str]:
        """
        Проверяем наличие структуры AlphaFold для UniProt ID
        """
        try:
            # AlphaFold API для проверки наличия структуры
            url = f"https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}"
            response = self.session.get(url, timeout=15)
            
            if response.status_code == 200:
                data = response.json()
                if data and len(data) > 0:
                    return uniprot_id  # Используем UniProt ID как AlphaFold ID
            
            return None
            
        except Exception as e:
            print(f"Ошибка проверки AlphaFold для {uniprot_id}: {e}")
            return None
    
    def _get_alphafold_info(self, alphafold_id: str) -> Dict:
        """
        Получение информации о структуре AlphaFold
        """
        try:
            url = f"https://alphafold.ebi.ac.uk/api/prediction/{alphafold_id}"
            response = self.session.get(url, timeout=15)
            
            if response.status_code == 200:
                data = response.json()
                if data and len(data) > 0:
                    structure_info = data[0]
                    
                    # Вычисляем средний pLDDT score (мера уверенности)
                    plddt_scores = structure_info.get('plddt', [])
                    avg_plddt = sum(plddt_scores) / len(plddt_scores) if plddt_scores else 0
                    
                    return {
                        'plddt': round(avg_plddt, 2),
                        'confidence': self._get_confidence_level(avg_plddt),
                        'model_url': f"https://alphafold.ebi.ac.uk/entry/{alphafold_id}",
                        'download_url': structure_info.get('pdbUrl', 'N/A'),
                        'version': structure_info.get('version', 'N/A')
                    }
            
            return {}
            
        except:
            return {}
    
    def _get_relevance_level(self, score: float) -> str:
        """Определение уровня релевантности"""
        if score == 100:
            return "exact_match"
        elif score >= 90:
            return "very_high"
        elif score >= 80:
            return "high"
        elif score >= 70:
            return "medium"
        elif score >= 60:
            return "low"
        else:
            return "very_low"
    
    def _get_confidence_level(self, plddt: float) -> str:
        """Определение уровня уверенности AlphaFold по pLDDT"""
        if plddt >= 90:
            return "very_high"
        elif plddt >= 70:
            return "confident"
        elif plddt >= 50:
            return "low"
        else:
            return "very_low"

def process_alphafold_search(csv_file_path: str, output_file: Optional[str] = None, max_results: int = 10) -> pd.DataFrame:
    """
    Обработка датасета с поиском в AlphaFold
    """
    if not os.path.exists(csv_file_path):
        print(f"Ошибка: Файл {csv_file_path} не найден!")
        return None
    
    df = pd.read_csv(csv_file_path)
    
    # Проверяем наличие необходимых колонок
    required_columns = ['nodeid', 'name', 'content']
    for col in required_columns:
        if col not in df.columns:
            print(f"Ошибка: В датасете отсутствует колонка '{col}'")
            return None
    
    print(f"Загружено записей: {len(df)}")
    print("Поиск в базе данных AlphaFold...")
    print("=" * 60)
    
    searcher = AlphaFoldSearcher()
    results = []
    
    for index, row in df.iterrows():
        print(f"\nОбработка {index + 1}/{len(df)}: {row['name']}")
        print(f"Название для поиска: {row['name']}")
        
        protein_name = row['name'].strip()
        result = searcher.search_alphafold_by_name(protein_name, max_results)
        
        similarity_info = result['detailed_results']
        
        # Формируем результат в нужном формате
        result_data = {
            'nodeid': row['nodeid'],
            'name': row['name'],
            'sequence': row['content'],
            'sequence_length': len(row['content']),
            'found_in_alphafold': result['found'],
            'alphafold_results_count': result['count'],
            'alphafold_ids': ', '.join(result['alphafold_ids']) if result['alphafold_ids'] else 'None',
            'similarity_info': json.dumps(similarity_info, ensure_ascii=False) if similarity_info else 'None',
            'max_relevance': max([item['relevance_score'] for item in similarity_info]) if similarity_info else 0,
            'best_match': similarity_info[0]['alphafold_id'] if similarity_info else 'None',
            'error': result['error'] if result['error'] else 'None'
        }
        
        results.append(result_data)
        
        status = "✓ НАЙДЕНО" if result['found'] else "✗ НЕ НАЙДЕНО"
        print(f"  {status} - {result['count']} результатов")
        
        if result['found']:
            best_match = similarity_info[0]
            print(f"  Лучшее совпадение: {best_match['alphafold_id']}")
            print(f"  Релевантность: {best_match['relevance_score']}%")
            if best_match.get('plddt_score') != 'N/A':
                print(f"  Уверенность модели: {best_match['confidence_level']} (pLDDT: {best_match['plddt_score']})")
        
        time.sleep(1)  # Уменьшаем паузу для ускорения
    
    # Создаем DataFrame с результатами
    results_df = pd.DataFrame(results)
    
    if output_file:
        results_df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"\nРезультаты сохранены в: {output_file}")
    
    return results_df

def create_alphafold_detailed_report(results_df: pd.DataFrame, output_file: str = "alphafold_detailed_report.csv") -> pd.DataFrame:
    """
    Создание детального отчета по AlphaFold
    """
    detailed_data = []
    
    for _, row in results_df.iterrows():
        if row['found_in_alphafold'] and row['similarity_info'] != 'None':
            try:
                similarity_data = json.loads(row['similarity_info'])
                for match in similarity_data:
                    detailed_data.append({
                        'nodeid': row['nodeid'],
                        'query_name': row['name'],
                        'alphafold_id': match['alphafold_id'],
                        'uniprot_id': match['uniprot_id'],
                        'relevance_score': match['relevance_score'],
                        'relevance_level': match['relevance_level'],
                        'protein_name': match.get('protein_name', 'N/A'),
                        'gene_name': match.get('gene_name', 'N/A'),
                        'organism': match.get('organism', 'N/A'),
                        'plddt_score': match.get('plddt_score', 'N/A'),
                        'confidence_level': match.get('confidence_level', 'N/A'),
                        'sequence_length': match.get('sequence_length', 0)
                    })
            except Exception as e:
                print(f"Ошибка при обработке детальных данных: {e}")
    
    if detailed_data:
        detailed_df = pd.DataFrame(detailed_data)
        detailed_df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"Детальный отчет AlphaFold сохранен в: {output_file}")
        return detailed_df
    else:
        print("Нет данных для детального отчета AlphaFold")
        return None

def main():
    """
    Основная функция для поиска в AlphaFold
    """
    csv_file_path = input("Введите путь к CSV файлу с данными: ").strip()
    
    if not os.path.exists(csv_file_path):
        print(f"Файл {csv_file_path} не найден!")
        return
    
    output_file = input("Введите имя для выходного файла (или нажмите Enter для 'alphafold_results.csv'): ").strip()
    if not output_file:
        output_file = "alphafold_results.csv"
    
    try:
        max_results = int(input("Максимальное количество результатов на запрос (по умолчанию 10): ").strip() or "10")
    except ValueError:
        max_results = 10
    
    print(f"\nНастройки поиска:")
    print(f"  Файл данных: {csv_file_path}")
    print(f"  Выходной файл: {output_file}")
    print(f"  Максимум результатов: {max_results}")
    print("=" * 60)
    
    # Запускаем поиск в AlphaFold
    results = process_alphafold_search(
        csv_file_path=csv_file_path,
        output_file=output_file,
        max_results=max_results
    )
    
    if results is not None:
        # Статистика
        total = len(results)
        found = results['found_in_alphafold'].sum()
        
        print(f"\nСтатистика поиска в AlphaFold:")
        print(f"  Всего записей: {total}")
        print(f"  Найдено в AlphaFold: {found} ({found/total*100:.1f}%)")
        
        if found > 0:
            # Создаем детальный отчет
            detailed_report = create_alphafold_detailed_report(results)
            
            # Дополнительная статистика
            avg_relevance = results[results['max_relevance'] > 0]['max_relevance'].mean()
            exact_matches = len(results[results['max_relevance'] == 100])
            
            print(f"  Средняя релевантность: {avg_relevance:.1f}%")
            print(f"  Точных совпадений: {exact_matches}")

if __name__ == "__main__":
    main()
# Out:
# Настройки поиска:
#   Файл данных: /Users/ivangolovkin/VSCode/MyProjects/proteins.csv
#   Выходной файл: test_AF4
#   Максимум результатов: 10
# ============================================================
# Загружено записей: 300
# Поиск в базе данных AlphaFold...
# ============================================================
#
# Обработка 1/300: SARS-CoV-2 nucleocapsid (N)
# Название для поиска: SARS-CoV-2 nucleocapsid (N)
#   ✓ НАЙДЕНО - 6 результатов
#   Лучшее совпадение: P04439
#   Релевантность: 45.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 2/300: HSA
# Название для поиска: HSA
#   ✓ НАЙДЕНО - 10 результатов
#   Лучшее совпадение: A8AWU7
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 3/300: Trypsin
# Название для поиска: Trypsin
#   ✓ НАЙДЕНО - 10 результатов
#   Лучшее совпадение: P00761
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 4/300: Spike RBD
# Название для поиска: Spike RBD
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 5/300: sfGFP
# Название для поиска: sfGFP
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 6/300: Acute Myeloid Leukemia Marker CD33
# Название для поиска: Acute Myeloid Leukemia Marker CD33
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 7/300: lysozyme
# Название для поиска: lysozyme
#   ✓ НАЙДЕНО - 10 результатов
#   Лучшее совпадение: P86383
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 8/300: BcII β-lactamases
# Название для поиска: BcII β-lactamases
#   ✓ НАЙДЕНО - 1 результатов
#   Лучшее совпадение: P04190
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 9/300: TEM-1
# Название для поиска: TEM-1
#   ✓ НАЙДЕНО - 8 результатов
#   Лучшее совпадение: P38987
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 10/300: NmcA β-lactamase
# Название для поиска: NmcA β-lactamase
#   ✓ НАЙДЕНО - 1 результатов
#   Лучшее совпадение: P52676
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 11/300: RR6
# Название для поиска: RR6
#   ✓ НАЙДЕНО - 9 результатов
#   Лучшее совпадение: Q7XQA6
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 12/300: human prostate-specific antigen
# Название для поиска: human prostate-specific antigen
#   ✓ НАЙДЕНО - 8 результатов
#   Лучшее совпадение: P07288
#   Релевантность: 40.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 13/300: variant surface glycoprotein
# Название для поиска: variant surface glycoprotein
#   ✓ НАЙДЕНО - 6 результатов
#   Лучшее совпадение: P01730
#   Релевантность: 40.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 14/300: Human Lysozyme
# Название для поиска: Human Lysozyme
#   ✓ НАЙДЕНО - 5 результатов
#   Лучшее совпадение: P00709
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 15/300: HER2
# Название для поиска: HER2
#   ✓ НАЙДЕНО - 10 результатов
#   Лучшее совпадение: Q03557
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 16/300: Botulinum neurotoxin A
# Название для поиска: Botulinum neurotoxin A
#   ✓ НАЙДЕНО - 7 результатов
#   Лучшее совпадение: P0DPI0
#   Релевантность: 80.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 17/300: CEACAM6 (glycosylphosphoinositol (GPI)-linked cell surface PROTEIN)
# Название для поиска: CEACAM6 (glycosylphosphoinositol (GPI)-linked cell surface PROTEIN)
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 18/300: Abrin
# Название для поиска: Abrin
#   ✓ НАЙДЕНО - 6 результатов
#   Лучшее совпадение: P11140
#   Релевантность: 90.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 19/300: Xenopus nucleoporin 98kDa (Nup98)
# Название для поиска: Xenopus nucleoporin 98kDa (Nup98)
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 20/300: recombinant EGFR
# Название для поиска: recombinant EGFR
#   ✓ НАЙДЕНО - 9 результатов
#   Лучшее совпадение: P35070
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 21/300: BclA
# Название для поиска: BclA
#   ✓ НАЙДЕНО - 6 результатов
#   Лучшее совпадение: Q8GQN9
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 22/300: gerQ
# Название для поиска: gerQ
#   ✓ НАЙДЕНО - 9 результатов
#   Лучшее совпадение: P39620
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 23/300: SODA1
# Название для поиска: SODA1
#   ✓ НАЙДЕНО - 5 результатов
#   Лучшее совпадение: P50058
#   Релевантность: 100.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 24/300: SOD15
# Название для поиска: SOD15
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 25/300: p5303
# Название для поиска: p5303
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 26/300: 9cq4_H_L
# Название для поиска: 9cq4_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 27/300: 9cq8_C_E
# Название для поиска: 9cq8_C_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 28/300: 9cql_J_K
# Название для поиска: 9cql_J_K
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 29/300: 8rl5_K
# Название для поиска: 8rl5_K
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 30/300: 8rl7_B
# Название для поиска: 8rl7_B
#   ✓ НАЙДЕНО - 1 результатов
#   Лучшее совпадение: P17076
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 31/300: 8rl9_D
# Название для поиска: 8rl9_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 32/300: 8rlc_D
# Название для поиска: 8rlc_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 33/300: 8rlc_C
# Название для поиска: 8rlc_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 34/300: 8w3r_A_a
# Название для поиска: 8w3r_A_a
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 35/300: 8xt9_A
# Название для поиска: 8xt9_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 36/300: 9hk1_H_L
# Название для поиска: 9hk1_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 37/300: 9j7y_H
# Название для поиска: 9j7y_H
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 38/300: 8zhq_D_A
# Название для поиска: 8zhq_D_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 39/300: 8zhq_C_B
# Название для поиска: 8zhq_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 40/300: 8zr4_A_B
# Название для поиска: 8zr4_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 41/300: 9h76_B
# Название для поиска: 9h76_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 42/300: 9l1s_C_B
# Название для поиска: 9l1s_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 43/300: 8t6m_B_A
# Название для поиска: 8t6m_B_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 44/300: 8qgx_B
# Название для поиска: 8qgx_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 45/300: 8si1_H_L
# Название для поиска: 8si1_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 46/300: 8sj4_H_L
# Название для поиска: 8sj4_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 47/300: 8sj4_F_D
# Название для поиска: 8sj4_F_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 48/300: 8sj6_A_B
# Название для поиска: 8sj6_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 49/300: 8sja_D_C
# Название для поиска: 8sja_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 50/300: 8ume_H_L
# Название для поиска: 8ume_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 51/300: 8ybl_B
# Название для поиска: 8ybl_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 52/300: 8ybm_B
# Название для поиска: 8ybm_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 53/300: 8ybn_B
# Название для поиска: 8ybn_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 54/300: 8ybo_B
# Название для поиска: 8ybo_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 55/300: 8ybp_B
# Название для поиска: 8ybp_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 56/300: 8zpp_H_L
# Название для поиска: 8zpp_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 57/300: 9cbn_A_B
# Название для поиска: 9cbn_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 58/300: 9cbn_E_F
# Название для поиска: 9cbn_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 59/300: 9cn2_B_b
# Название для поиска: 9cn2_B_b
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 60/300: 8s6z_A_B
# Название для поиска: 8s6z_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 61/300: 8v9d_K_L
# Название для поиска: 8v9d_K_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 62/300: 8jag_H_L
# Название для поиска: 8jag_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 63/300: 8jkf_H_L
# Название для поиска: 8jkf_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 64/300: 8jqm_H_L
# Название для поиска: 8jqm_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 65/300: 8jqn_H_L
# Название для поиска: 8jqn_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 66/300: 8rby_B
# Название для поиска: 8rby_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 67/300: 8v5q_H_L
# Название для поиска: 8v5q_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 68/300: 8v5v_b_d
# Название для поиска: 8v5v_b_d
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 69/300: 8v93_A_C
# Название для поиска: 8v93_A_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 70/300: 8v93_B_L
# Название для поиска: 8v93_B_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 71/300: 8vc7_J_D
# Название для поиска: 8vc7_J_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 72/300: 8vti_D_C
# Название для поиска: 8vti_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 73/300: 8xef_B_C
# Название для поиска: 8xef_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 74/300: 8xef_D_E
# Название для поиска: 8xef_D_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 75/300: 8xrq_B_C
# Название для поиска: 8xrq_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 76/300: 8y4w_B
# Название для поиска: 8y4w_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 77/300: 8yvj_A
# Название для поиска: 8yvj_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 78/300: 8yvo_A
# Название для поиска: 8yvo_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 79/300: 9b3k_H_L
# Название для поиска: 9b3k_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 80/300: 9b8j_E_F
# Название для поиска: 9b8j_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 81/300: 9b8j_H_L
# Название для поиска: 9b8j_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 82/300: 9bsu_E
# Название для поиска: 9bsu_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 83/300: 9bsv_D
# Название для поиска: 9bsv_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 84/300: 9ekf_D_I
# Название для поиска: 9ekf_D_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 85/300: 9ert_B
# Название для поиска: 9ert_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 86/300: 9erw_E
# Название для поиска: 9erw_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 87/300: 9etj_C
# Название для поиска: 9etj_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 88/300: 9etl_D
# Название для поиска: 9etl_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 89/300: 9jqt_B_C
# Название для поиска: 9jqt_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 90/300: 8jkh_h_l
# Название для поиска: 8jkh_h_l
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 91/300: 8jqs_h_l
# Название для поиска: 8jqs_h_l
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 92/300: 8xfp_E
# Название для поиска: 8xfp_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 93/300: 8xfs_F
# Название для поиска: 8xfs_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 94/300: 8y31_B_A
# Название для поиска: 8y31_B_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 95/300: 9b2w_B_C
# Название для поиска: 9b2w_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 96/300: 9b82_H_L
# Название для поиска: 9b82_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 97/300: 9dh2_A_D
# Название для поиска: 9dh2_A_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 98/300: 9dwe_H_L
# Название для поиска: 9dwe_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 99/300: 9dzq_G_I
# Название для поиска: 9dzq_G_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 100/300: 9dzq_C
# Название для поиска: 9dzq_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 101/300: 9dzq_E
# Название для поиска: 9dzq_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 102/300: 8rj7_B
# Название для поиска: 8rj7_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 103/300: 8uzc_H_L
# Название для поиска: 8uzc_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 104/300: 8zd5_H_I
# Название для поиска: 8zd5_H_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 105/300: 9f6o_B
# Название для поиска: 9f6o_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 106/300: 9bt8_A
# Название для поиска: 9bt8_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 107/300: 9cx3_H_L
# Название для поиска: 9cx3_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 108/300: 8rw9_D
# Название для поиска: 8rw9_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 109/300: 8rwf_C
# Название для поиска: 8rwf_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 110/300: 9b9y_N
# Название для поиска: 9b9y_N
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 111/300: 9bif_H_L
# Название для поиска: 9bif_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 112/300: 9c44_H_L
# Название для поиска: 9c44_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 113/300: 9co6_E
# Название для поиска: 9co6_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 114/300: 9e6k_H_L
# Название для поиска: 9e6k_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 115/300: 9ivk_H_L
# Название для поиска: 9ivk_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 116/300: 8qz6_B
# Название для поиска: 8qz6_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 117/300: 8uwz_C_D
# Название для поиска: 8uwz_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 118/300: 8wyj_Q_R
# Название для поиска: 8wyj_Q_R
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 119/300: 8wyj_S_T
# Название для поиска: 8wyj_S_T
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 120/300: 8wz3_D_F
# Название для поиска: 8wz3_D_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 121/300: 8wz5_H_L
# Название для поиска: 8wz5_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 122/300: 8xcd_H_L
# Название для поиска: 8xcd_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 123/300: 9axl_H_L
# Название для поиска: 9axl_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 124/300: 9b2c_H_L
# Название для поиска: 9b2c_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 125/300: 9bdf_B_I
# Название для поиска: 9bdf_B_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 126/300: 9bdg_D_G
# Название для поиска: 9bdg_D_G
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 127/300: 9dez_H_L
# Название для поиска: 9dez_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 128/300: 9df0_H_L
# Название для поиска: 9df0_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 129/300: 9dx6_B_C
# Название для поиска: 9dx6_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 130/300: 9eot_B
# Название для поиска: 9eot_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 131/300: 8pxo_D_C
# Название для поиска: 8pxo_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 132/300: 8r40_R_r
# Название для поиска: 8r40_R_r
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 133/300: 8s79_C
# Название для поиска: 8s79_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 134/300: 8vgn_A_B
# Название для поиска: 8vgn_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 135/300: 8vgo_A_B
# Название для поиска: 8vgo_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 136/300: 8ywq_H_L
# Название для поиска: 8ywq_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 137/300: 8ywr_H_L
# Название для поиска: 8ywr_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 138/300: 9ctu_D_C
# Название для поиска: 9ctu_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 139/300: 9ctw_D_C
# Название для поиска: 9ctw_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 140/300: 9fvb_C
# Название для поиска: 9fvb_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 141/300: 9fvc_H
# Название для поиска: 9fvc_H
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 142/300: 9fve_B
# Название для поиска: 9fve_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 143/300: 7lz6_C_D
# Название для поиска: 7lz6_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 144/300: 8rrn_H_L
# Название для поиска: 8rrn_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 145/300: 8us0_N_O
# Название для поиска: 8us0_N_O
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 146/300: 8vgh_H_G
# Название для поиска: 8vgh_H_G
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 147/300: 8vgi_F_E
# Название для поиска: 8vgi_F_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 148/300: 8vgj_F_E
# Название для поиска: 8vgj_F_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 149/300: 8vgk_F_E
# Название для поиска: 8vgk_F_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 150/300: 8vgp_H_L
# Название для поиска: 8vgp_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 151/300: 9fkd_H_L
# Название для поиска: 9fkd_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 152/300: 9fww_B
# Название для поиска: 9fww_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 153/300: 9jub_B_C
# Название для поиска: 9jub_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 154/300: 8s6m_H_L
# Название для поиска: 8s6m_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 155/300: 8s6m_I_M
# Название для поиска: 8s6m_I_M
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 156/300: 9gwt_H_L
# Название для поиска: 9gwt_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 157/300: 9au2_D_I
# Название для поиска: 9au2_D_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 158/300: 8rek_H_L
# Название для поиска: 8rek_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 159/300: 8up2_A_B
# Название для поиска: 8up2_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 160/300: 8wpw_A_B
# Название для поиска: 8wpw_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 161/300: 8wpw_C_D
# Название для поиска: 8wpw_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 162/300: 8wpw_H_L
# Название для поиска: 8wpw_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 163/300: 9asd_H_L
# Название для поиска: 9asd_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 164/300: 9atm_H_L
# Название для поиска: 9atm_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 165/300: 9atm_I_M
# Название для поиска: 9atm_I_M
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 166/300: 9au1_M_N
# Название для поиска: 9au1_M_N
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 167/300: 9au1_H_L
# Название для поиска: 9au1_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 168/300: 8y0q_H_L
# Название для поиска: 8y0q_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 169/300: 8k18_C_D
# Название для поиска: 8k18_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 170/300: 8k19_A_B
# Название для поиска: 8k19_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 171/300: 8v5l_H_L
# Название для поиска: 8v5l_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 172/300: 8v5l_B_C
# Название для поиска: 8v5l_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 173/300: 8v5p_H_L
# Название для поиска: 8v5p_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 174/300: 8vdl_H_L
# Название для поиска: 8vdl_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 175/300: 8vqd_C_B
# Название для поиска: 8vqd_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 176/300: 8s4u_B
# Название для поиска: 8s4u_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 177/300: 8s5w_B
# Название для поиска: 8s5w_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 178/300: 8s61_B
# Название для поиска: 8s61_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 179/300: 8vdf_H_L
# Название для поиска: 8vdf_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 180/300: 8vdg_H_K
# Название для поиска: 8vdg_H_K
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 181/300: 8vgv_C_D
# Название для поиска: 8vgv_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 182/300: 8vgw_C_D
# Название для поиска: 8vgw_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 183/300: 8vh1_C_D
# Название для поиска: 8vh1_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 184/300: 9g5k_B
# Название для поиска: 9g5k_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 185/300: 8qj2_D
# Название для поиска: 8qj2_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 186/300: 8uy6_B
# Название для поиска: 8uy6_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 187/300: 8weo_C
# Название для поиска: 8weo_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 188/300: 8wfh_E_e
# Название для поиска: 8wfh_E_e
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 189/300: 8wfm_A_a
# Название для поиска: 8wfm_A_a
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 190/300: 8wrd_H_L
# Название для поиска: 8wrd_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 191/300: 8zdw_U_R
# Название для поиска: 8zdw_U_R
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 192/300: 8vut_H_L
# Название для поиска: 8vut_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 193/300: 8vym_D_E
# Название для поиска: 8vym_D_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 194/300: 8vym_K_H
# Название для поиска: 8vym_K_H
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 195/300: 8wcg_C
# Название для поиска: 8wcg_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 196/300: 8wcg_b
# Название для поиска: 8wcg_b
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 197/300: 8xps_B
# Название для поиска: 8xps_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 198/300: 9ato_D
# Название для поиска: 9ato_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 199/300: 8ukh_H_L
# Название для поиска: 8ukh_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 200/300: 8ulf_H_L
# Название для поиска: 8ulf_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 201/300: 8vuh_H_L
# Название для поиска: 8vuh_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 202/300: 8vul_H_L
# Название для поиска: 8vul_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 203/300: 8vur_H_L
# Название для поиска: 8vur_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 204/300: 8vus_E_F
# Название для поиска: 8vus_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 205/300: 8vuu_H_L
# Название для поиска: 8vuu_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 206/300: 8vuy_H_L
# Название для поиска: 8vuy_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 207/300: 8y4a_H_L
# Название для поиска: 8y4a_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 208/300: 8ysf_C
# Название для поиска: 8ysf_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 209/300: 8ysh_A
# Название для поиска: 8ysh_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 210/300: 8yxi_C_B
# Название для поиска: 8yxi_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 211/300: 8zoy_B
# Название для поиска: 8zoy_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 212/300: 8zpb_B
# Название для поиска: 8zpb_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 213/300: 9clp_H_L
# Название для поиска: 9clp_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 214/300: 9jbq_A_B
# Название для поиска: 9jbq_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 215/300: 8keh_G_F
# Название для поиска: 8keh_G_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 216/300: 8zer_A
# Название для поиска: 8zer_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 217/300: 8jxr_H_L
# Название для поиска: 8jxr_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 218/300: 8jxr_B
# Название для поиска: 8jxr_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 219/300: 8qw4_B
# Название для поиска: 8qw4_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 220/300: 8rvn_H_L
# Название для поиска: 8rvn_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 221/300: 8sow_C_c
# Название для поиска: 8sow_C_c
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 222/300: 8soz_C_c
# Название для поиска: 8soz_C_c
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 223/300: 8tzy_A_B
# Название для поиска: 8tzy_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 224/300: 8u3s_B
# Название для поиска: 8u3s_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 225/300: 8uvy_B
# Название для поиска: 8uvy_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 226/300: 8w90_A
# Название для поиска: 8w90_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 227/300: 8y4c_H_L
# Название для поиска: 8y4c_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 228/300: 8z8m_B
# Название для поиска: 8z8m_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 229/300: 8z8v_B
# Название для поиска: 8z8v_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 230/300: 9bge_D_E
# Название для поиска: 9bge_D_E
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 231/300: 8q6r_A
# Название для поиска: 8q6r_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 232/300: 8q7o_A
# Название для поиска: 8q7o_A
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 233/300: 8tbb_H_L
# Название для поиска: 8tbb_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 234/300: 8tft_I_M
# Название для поиска: 8tft_I_M
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 235/300: 8tuz_H_L
# Название для поиска: 8tuz_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 236/300: 8tv3_H_L
# Название для поиска: 8tv3_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 237/300: 8tvd_H_L
# Название для поиска: 8tvd_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 238/300: 8tvj_H_L
# Название для поиска: 8tvj_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 239/300: 8ug9_M
# Название для поиска: 8ug9_M
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 240/300: 9iy2_H_L
# Название для поиска: 9iy2_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 241/300: 9iy2_E_F
# Название для поиска: 9iy2_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 242/300: 9ijd_D_d
# Название для поиска: 9ijd_D_d
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 243/300: 8zhe_H_L
# Название для поиска: 8zhe_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 244/300: 8zhg_H_L
# Название для поиска: 8zhg_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 245/300: 8zhk_E_D
# Название для поиска: 8zhk_E_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 246/300: 8zhn_G_I
# Название для поиска: 8zhn_G_I
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 247/300: 8q3j_C_B
# Название для поиска: 8q3j_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 248/300: 8kdr_H_L
# Название для поиска: 8kdr_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 249/300: 8keo_E_D
# Название для поиска: 8keo_E_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 250/300: 8tnj_D_C
# Название для поиска: 8tnj_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 251/300: 8tnj_E_F
# Название для поиска: 8tnj_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 252/300: 8u5l_F_f
# Название для поиска: 8u5l_F_f
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 253/300: 8sdh_H_L
# Название для поиска: 8sdh_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 254/300: 8to9_D_F
# Название для поиска: 8to9_D_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 255/300: 8k9b_A_B
# Название для поиска: 8k9b_A_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 256/300: 8qkr_B_C
# Название для поиска: 8qkr_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 257/300: 8qks_C_B
# Название для поиска: 8qks_C_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 258/300: 8vcr_D_F
# Название для поиска: 8vcr_D_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 259/300: 8yww_H_h
# Название для поиска: 8yww_H_h
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 260/300: 8yww_E_D
# Название для поиска: 8yww_E_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 261/300: 8ywx_E_D
# Название для поиска: 8ywx_E_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 262/300: 9ber_H_L
# Название для поиска: 9ber_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 263/300: 9bew_C_D
# Название для поиска: 9bew_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 264/300: 9bew_H_L
# Название для поиска: 9bew_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 265/300: 9g7k_C
# Название для поиска: 9g7k_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 266/300: 8tgv_E_F
# Название для поиска: 8tgv_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 267/300: 8thz_H_L
# Название для поиска: 8thz_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 268/300: 8thz_E_F
# Название для поиска: 8thz_E_F
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 269/300: 8tjn_C_D
# Название для поиска: 8tjn_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 270/300: 8vif_H_L
# Название для поиска: 8vif_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 271/300: 8vww_B_C
# Название для поиска: 8vww_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 272/300: 8vww_H_L
# Название для поиска: 8vww_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 273/300: 8w4f_D
# Название для поиска: 8w4f_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 274/300: 8zgu_H_L
# Название для поиска: 8zgu_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 275/300: 9bir_B
# Название для поиска: 9bir_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 276/300: 9euo_H_L
# Название для поиска: 9euo_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 277/300: 9g1y_C
# Название для поиска: 9g1y_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 278/300: 9g2g_C
# Название для поиска: 9g2g_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 279/300: 9g48_C
# Название для поиска: 9g48_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 280/300: 9g4g_B
# Название для поиска: 9g4g_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 281/300: 9g5l_B
# Название для поиска: 9g5l_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 282/300: 9g5z_C
# Название для поиска: 9g5z_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 283/300: 8udz_C_D
# Название для поиска: 8udz_C_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 284/300: 8q5y_R_L
# Название для поиска: 8q5y_R_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 285/300: 8k33_B
# Название для поиска: 8k33_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 286/300: 8k3a_B
# Название для поиска: 8k3a_B
#   ✓ НАЙДЕНО - 1 результатов
#   Лучшее совпадение: O60423
#   Релевантность: 30.0%
#   Уверенность модели: very_low (pLDDT: 0)
#
# Обработка 287/300: 8k3l_B
# Название для поиска: 8k3l_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 288/300: 8rz0_B_b
# Название для поиска: 8rz0_B_b
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 289/300: 8rz1_A_a
# Название для поиска: 8rz1_A_a
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 290/300: 8rz2_B_C
# Название для поиска: 8rz2_B_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 291/300: 8tg9_H_L
# Название для поиска: 8tg9_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 292/300: 8trv_C_G
# Название для поиска: 8trv_C_G
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 293/300: 8vvk_D_C
# Название для поиска: 8vvk_D_C
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 294/300: 8vvl_H_L
# Название для поиска: 8vvl_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 295/300: 8w1v_D
# Название для поиска: 8w1v_D
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 296/300: 8x7n_B
# Название для поиска: 8x7n_B
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 297/300: 8xse_H_L
# Название для поиска: 8xse_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 298/300: 8xse_M_N
# Название для поиска: 8xse_M_N
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 299/300: 8xsf_H_L
# Название для поиска: 8xsf_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Обработка 300/300: 8xsj_H_L
# Название для поиска: 8xsj_H_L
#   ✗ НЕ НАЙДЕНО - 0 результатов
#
# Результаты сохранены в: test_AF4
#
# Статистика поиска в AlphaFold:
#   Всего записей: 300
#   Найдено в AlphaFold: 20 (6.7%)
# Детальный отчет AlphaFold сохранен в: alphafold_detailed_report.csv
#   Средняя релевантность: 65.2%
#   Точных совпадений: 8
